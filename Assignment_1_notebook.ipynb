# %% [markdown]
# <a href="https://colab.research.google.com/github/NicChad08/SCIE1001-Worksheet-v2/blob/main/Assignment_1_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
def f(x):
    return x**3 - 3*x**2 + 1

# %%
x_vals = [0,3]

# %%
print
